# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score

# %%
df = pd.read_csv('data2.csv')
df['timestamp'] = pd.to_datetime(df['timestamp'])

# %%
features = df[['wallet_id', 'timestamp', 'amount', 'counterparty_wallet', 'mixing_service_used']]
features
# Out:
#                             wallet_id           timestamp  amount  \
# 0  1HLoD9E4SDFFPDiYfNYnkBLQ85Y51J3Zb1 2023-01-01 08:00:00     1.5
# 1  3Cbq7aT1tY8kMxWLbitaG7yT6bPbKChq64 2023-01-01 09:15:00     2.0
# 2   1FvEiJoxPAAwbHqvAeCB1L2b8vPwotCiR 2023-01-01 10:30:00     1.8
# 3  3Cbq7aT1tY8kMxWLbitaG7yT6bPbKChq64 2023-01-01 12:00:00     3.2
# 4  1HLoD9E4SDFFPDiYfNYnkBLQ85Y51J3Zb1 2023-01-01 14:45:00     2.3
# 5  3Cbq7aT1tY8kMxWLbitaG7yT6bPbKChq64 2023-01-01 16:30:00     1.6
# 6   1FvEiJoxPAAwbHqvAeCB1L2b8vPwotCiR 2023-01-01 18:15:00     2.5
# 7  3Cbq7aT1tY8kMxWLbitaG7yT6bPbKChq64 2023-01-01 20:00:00     2.8
# 8  1HLoD9E4SDFFPDiYfNYnkBLQ85Y51J3Zb1 2023-01-01 21:45:00     1.9
# 9  3Cbq7aT1tY8kMxWLbitaG7yT6bPbKChq64 2023-01-01 23:30:00     2.2
#
#                   counterparty_wallet  mixing_service_used
# 0  3Cbq7aT1tY8kMxWLbitaG7yT6bPbKChq64                    0
# 1  1HLoD9E4SDFFPDiYfNYnkBLQ85Y51J3Zb1                    1
# 2  3Cbq7aT1tY8kMxWLbitaG7yT6bPbKChq64                    0
# 3   1FvEiJoxPAAwbHqvAeCB1L2b8vPwotCiR                    0
# 4  3Cbq7aT1tY8kMxWLbitaG7yT6bPbKChq64                    1
# 5   1FvEiJoxPAAwbHqvAeCB1L2b8vPwotCiR                    0
# 6  3Cbq7aT1tY8kMxWLbitaG7yT6bPbKChq64                    1
# 7  1HLoD9E4SDFFPDiYfNYnkBLQ85Y51J3Zb1                    0
# 8  3Cbq7aT1tY8kMxWLbitaG7yT6bPbKChq64                    0
# 9  1HLoD9E4SDFFPDiYfNYnkBLQ85Y51J3Zb1                    1

# %%
## Wallet-Level Aggregation
wallet_aggregated = features.groupby('wallet_id').agg({
    'timestamp': 'count',
    'amount': 'sum',
    'counterparty_wallet': pd.Series.nunique,
    'mixing_service_used': 'mean'  # Assuming mixing_service_used is binary (0 or 1)
}).reset_index()


wallet_aggregated
# Out:
#                             wallet_id  timestamp  amount  counterparty_wallet  \
# 0   1FvEiJoxPAAwbHqvAeCB1L2b8vPwotCiR          2     4.3                    1
# 1  1HLoD9E4SDFFPDiYfNYnkBLQ85Y51J3Zb1          3     5.7                    1
# 2  3Cbq7aT1tY8kMxWLbitaG7yT6bPbKChq64          5    11.8                    2
#
#    mixing_service_used
# 0             0.500000
# 1             0.333333
# 2             0.400000

# %%
time_aggregated = features.groupby(['wallet_id', pd.Grouper(key='timestamp', freq='D')]).agg({
    'amount': 'sum',
}).reset_index()

# %%
aggregated_results = pd.merge(wallet_aggregated, time_aggregated, on='wallet_id', how='left', suffixes=('_total', '_daily'))
aggregated_results
# Out:
#                             wallet_id  timestamp_total  amount_total  \
# 0   1FvEiJoxPAAwbHqvAeCB1L2b8vPwotCiR                2           4.3
# 1  1HLoD9E4SDFFPDiYfNYnkBLQ85Y51J3Zb1                3           5.7
# 2  3Cbq7aT1tY8kMxWLbitaG7yT6bPbKChq64                5          11.8
#
#    counterparty_wallet  mixing_service_used timestamp_daily  amount_daily
# 0                    1             0.500000      2023-01-01           4.3
# 1                    1             0.333333      2023-01-01           5.7
# 2                    2             0.400000      2023-01-01          11.8

# %%
non_numeric_columns = ['wallet_id', 'timestamp_daily']
non_numeric_data = aggregated_results[non_numeric_columns]
non_numeric_data
# Out:
#                             wallet_id timestamp_daily
# 0   1FvEiJoxPAAwbHqvAeCB1L2b8vPwotCiR      2023-01-01
# 1  1HLoD9E4SDFFPDiYfNYnkBLQ85Y51J3Zb1      2023-01-01
# 2  3Cbq7aT1tY8kMxWLbitaG7yT6bPbKChq64      2023-01-01

# %%
numeric_data = aggregated_results.drop(columns=non_numeric_columns)
numeric_data
# Out:
#    timestamp_total  amount_total  counterparty_wallet  mixing_service_used  \
# 0                2           4.3                    1             0.500000
# 1                3           5.7                    1             0.333333
# 2                5          11.8                    2             0.400000
#
#    amount_daily
# 0           4.3
# 1           5.7
# 2          11.8

# %%
scaler = StandardScaler()
scaled_features_numeric = scaler.fit_transform(numeric_data)

# %%
scaled_features = pd.concat([non_numeric_data, pd.DataFrame(scaled_features_numeric, columns=numeric_data.columns)], axis=1)
scaled_features
# Out:
#                             wallet_id timestamp_daily  timestamp_total  \
# 0   1FvEiJoxPAAwbHqvAeCB1L2b8vPwotCiR      2023-01-01        -1.069045
# 1  1HLoD9E4SDFFPDiYfNYnkBLQ85Y51J3Zb1      2023-01-01        -0.267261
# 2  3Cbq7aT1tY8kMxWLbitaG7yT6bPbKChq64      2023-01-01         1.336306
#
#    amount_total  counterparty_wallet  mixing_service_used  amount_daily
# 0     -0.911109            -0.707107             1.297771     -0.911109
# 1     -0.481147            -0.707107            -1.135550     -0.481147
# 2      1.392256             1.414214            -0.162221      1.392256

# %%
silhouette_avg = silhouette_score(scaled_features)
print(f"Silhouette Score for Clustering: {silhouette_avg}")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[63], line 1
# ----> 1 silhouette_avg = silhouette_score(scaled_features)
#       2 print(f"Silhouette Score for Clustering: {silhouette_avg}")
#
# File ~/.pyenv/versions/3.11.5/envs/deltax9-ds/lib/python3.11/site-packages/sklearn/utils/_param_validation.py:192, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     189 func_sig = signature(func)
#     191 # Map *args/**kwargs to the function signature
# --> 192 params = func_sig.bind(*args, **kwargs)
#     193 params.apply_defaults()
#     195 # ignore self/cls and positional/keyword markers
#
# File ~/.pyenv/versions/3.11.5/lib/python3.11/inspect.py:3212, in Signature.bind(self, *args, **kwargs)
#    3207 def bind(self, /, *args, **kwargs):
#    3208     """Get a BoundArguments object, that maps the passed `args`
#    3209     and `kwargs` to the function's signature.  Raises `TypeError`
#    3210     if the passed arguments can not be bound.
#    3211     """
# -> 3212     return self._bind(args, kwargs)
#
# File ~/.pyenv/versions/3.11.5/lib/python3.11/inspect.py:3127, in Signature._bind(self, args, kwargs, partial)
#    3125                 msg = 'missing a required argument: {arg!r}'
#    3126                 msg = msg.format(arg=param.name)
# -> 3127                 raise TypeError(msg) from None
#    3128 else:
#    3129     # We have a positional argument to process
#    3130     try:
#
# TypeError: missing a required argument: 'labels'
