# %%
from llama_index import download_loader
from llama_index.llms import AzureOpenAI
from llama_index.embeddings import AzureOpenAIEmbedding
from llama_index import VectorStoreIndex, SimpleDirectoryReader, ServiceContext
from llama_index.readers import StringIterableReader

# %%
api_key = "f0041499023d4093b7c65ce0add41a6c"
azure_endpoint = "https://alphabetagamma.openai.azure.com/"
api_version = "2023-07-01-preview"

embed_model = AzureOpenAIEmbedding(
    model="text-embedding-ada-002",
    deployment_name="text-embedding-ada-002",
    api_key=api_key,
    azure_endpoint=azure_endpoint,
    api_version=api_version,
)

llm = AzureOpenAI(
    model="gpt-35-turbo",
    deployment_name="gpt-35-turbo",
    api_key=api_key,
    azure_endpoint=azure_endpoint,
    api_version=api_version,
)

# %%
from llama_index import set_global_service_context

service_context = ServiceContext.from_defaults(
    llm=llm,
    embed_model=embed_model,
)

# %%
from bs4 import BeautifulSoup
from html2text import HTML2Text
from llama_index.readers import StringIterableReader
html_file = open("./", "r")
soup = BeautifulSoup(html_file, 'html.parser')
html2text_converter = HTML2Text()
plain_text = html2text_converter.handle(str(soup))
reader = StringIterableReader()
documents = reader.load_data(texts=plain_text)
print(plain_text)
index = VectorStoreIndex.from_documents(documents,service_context=service_context)
# Out:
# [Document(id_='81c58a39-1f8c-4bef-901c-16ba5bffe9ae', embedding=None, metadata={}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={}, hash='a062dd4952b935e430d409c4a5e5cd760e8781e3200d5c7e12a232dddba8a528', text='\n', start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'), Document(id_='3ada6462-71b0-468d-b8b9-6b055e88bb81', embedding=None, metadata={}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={}, hash='3030311c465d0a6787fd5f7e5c2a842a35ca3a70c2ef7f549c63dd1ef0248118', text='L', start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'), Document(id_='7be428a8-de56-4dd9-a1d1-a394f9751281', embedding=None, metadata={}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={}, hash='3030311c465d0a6787fd5f7e5c2a842a35ca3a70c2ef7f549c63dd1ef0248118', text='L', start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'), Document(id_='6d369682-98b7-4f25-89cd-267a51138d22', embedding=None, metadata={}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={}, hash='6b28fefafa8d57381c74590f902a55bfd2f259c140bfe842cebacf36bd9fcf9a', text='M', start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'), Document(id_='23627c21-73b7-4e9a-a901-b748ba09d25f', embedding=None, metadata={}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={}, hash='db42bb8c91b2a090542c6dc97a3477b206a8d36f27a96c3f06645afa7dc669cf', text='s', start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'), Document(id_='c88013c5-c42d-4655-9a96-02d9329cd00d', embedding=None, metadata={}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={}, hash='19ad4f109270169ad234dd5d2a951fe4c7f3c16b9357c1bd4ccef8525d676f64', text=' ', start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'), Document(id_='db06944b-a846-4fb5-9be3-57e98740cf2a', embedding=None, metadata={}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={}, hash='4a510c930baa5effe460243839a11df59d9043759240f2c36404c4fee37ab895', text='o', start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'), Document(id_='00e61e51-dcde-4efc-b9c9-29487110143d', embedding=None, metadata={}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={}, hash='7e2de008d13f6bba1a8a0596be5c190371c352f57379ef781a92d5a337184b52', text='f', start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'), Document(id_='bd12b7d7-239c-414c-b088-5fd9d9f47cee', embedding=None, metadata={}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={}, hash='7e2de008d13f6bba1a8a0596be5c190371c352f57379ef781a92d5a337184b52', text='f', start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'), Document(id_='1a29b944-16f5-45b6-bde3-32a1de83d97e', embedding=None, metadata={}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={}, hash='9bdb063af69279acc0300067ce7ef67041ae4ee99efd012f558f165a86028ffb', text='e', start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'), Document(id_='7ef5628d-bc5a-4785-a1a2-109ea063689e', embed ...

# %%
query = "What is LlamaIndex?"
query_engine = index.as_query_engine()
answer = query_engine.query(query)

print(answer.get_formatted_sources())
print("query was:", query)
print("answer was:", answer)
# Out:
# > Source (Doc id: 5d88dd3e-d769-4267-9f60-32f83ca53223): L
#
# > Source (Doc id: aec03dda-6f82-4a63-9e9f-82b8127f1459): L
# query was: What is LlamaIndex?
# answer was: The LlamaIndex is a measure used to assess the overall health and well-being of llama populations in a specific region. It takes into account factors such as population size, genetic diversity, and overall physical condition of the llamas.
